# %% [markdown]
# # Lists and Tuples <hr style="border:2.5px solid #126782"></hr>

# %% [markdown]
# <b>Roan Gayl Ydrian B. Agustin</b>
# <br>CpE - 2A

# %% [markdown]
# # Creating a List

# %%
numbers = [1,2,3,4,5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
len(numbers)
# Out:
# 5

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
len(fruits)
# Out:
# 3

# %%
mixed_list = [10, 'hello', 2,5, True]
mixed_list
# Out:
# [10, 'hello', 2, 5, True]

# %%
len(mixed_list)
# Out:
# 5

# %%
type(mixed_list)
# Out:
# list

# %% [markdown]
# # Indexing

# %%
numbers = [1,2,3,4,5]

# %%
numbers[1]
# Out:
# 2

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits[0]
# Out:
# 'apple'

# %% [markdown]
# # Modifying Elements

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits[0] = 'orange'

# %%
fruits
# Out:
# ['orange', 'banana', 'grape']

# %% [markdown]
# # Adding Elements

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits.append('orange')

# %%
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
fruits.insert(1,'blueberry')
fruits
# Out:
# ['apple', 'blueberry', 'banana', 'grape', 'orange']

# %% [markdown]
# # Removing Elements

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'banana' in fruits
# Out:
# True

# %%
fruits.remove('banana')
fruits
# Out:
# ['apple', 'grape']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['grape']

# %% [markdown]
# # Sort() and Sorted()

# %%
numbers = [3,1,5,4,2]
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
sorted(numbers,reverse=True)
# Out:
# [5, 4, 3, 2, 1]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Slicing

# %%
chars = ['a','b','c','x','y']
chars
# Out:
# ['a', 'b', 'c', 'x', 'y']

# %%
len(chars)
# Out:
# 5

# %%
sub = chars [1:4]
sub
# Out:
# ['b', 'c', 'x']

# %%
chars
# Out:
# ['a', 'b', 'c', 'x', 'y']

# %%
chars[0:5:2]
# Out:
# ['a', 'c', 'y']

# %% [markdown]
# # Tuple

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
len(my_tuple)
# Out:
# 5

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple[0]=0 #it will provide error beacaue tupple are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 my_tuple[2]=0
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple = (2,2,3,4,5)
my_tuple
# Out:
# (2, 2, 3, 4, 5)
