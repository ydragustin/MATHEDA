# %% [markdown]
# # Standard Normal Distribution <hr style="border:2.5px solid #126782"></hr>

# %% [markdown]
# <b>Roan Gayl Ydrian B. Agustin</b>
# <br>CpE - 2A

# %%
# imports and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # Z - score

# %%
# creating a dataframe
df = pd.DataFrame([1,2,2,3,3,3,4,4,5],
                  columns=['Dataset'])
df
# Out:
#    Dataset
# 0        1
# 1        2
# 2        2
# 3        3
# 4        3
# 5        3
# 6        4
# 7        4
# 8        5

# %%
# summary of statistics
df.describe
# Out:
# <bound method NDFrame.describe of    Dataset
# 0        1
# 1        2
# 2        2
# 3        3
# 4        3
# 5        3
# 6        4
# 7        4
# 8        5>

# %%
# Z - Scores
df['Z-scores']= stats.zscore(df['Dataset'],ddof=1)
df
# Out:
#    Dataset  Z-scores
# 0        1 -1.632993
# 1        2 -0.816497
# 2        2 -0.816497
# 3        3  0.000000
# 4        3  0.000000
# 5        3  0.000000
# 6        4  0.816497
# 7        4  0.816497
# 8        5  1.632993

# %%
# load dataset
df = pd.read_csv(r"data set\current-test.csv",
                 delimiter=',', 
                 index_col='Sample')
df
# Out:
#         Current
# Sample
# 1          12.0
# 2          15.0
# 3           8.3
# 4           9.7
# 5          12.0
# 6          13.9
# 7          14.1
# 8           9.2
# 9          12.4
# 10         13.7
# 11         10.6
# 12         21.5
# 13         12.0
# 14          9.3
# 15         11.2
# 16          3.3
# 17         12.4
# 18         12.3
# 19         13.8
# 20         10.5
# 21         10.4
# 22         15.0
# 23         12.7
# 24         14.4
# 25         11.0
# 26          9.1
# 27         10.2
# 28         12.4
# 29          7.0
# 30         14.8

# %%
df['Current'][3]
# Out:
# np.float64(8.3)

# %%
sample_1 = df['Current'][3:5].mean()
sample_1
# Out:
# np.float64(10.85)

# %%
# summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 1 to 30
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Current  30 non-null     float64
# dtypes: float64(1)
# memory usage: 1.5 KB

# %%
df.describe()
# Out:
#          Current
# count  30.000000
# mean   11.806667
# std     3.166629
# min     3.300000
# 25%    10.250000
# 50%    12.000000
# 75%    13.775000
# max    21.500000

# %%
df['Z-score']= stats.zscore(df['Current'],ddof=1)
df
# Out:
#         Current   Z-score
# Sample
# 1          12.0  0.061053
# 2          15.0  1.008433
# 3           8.3 -1.107382
# 4           9.7 -0.665271
# 5          12.0  0.061053
# 6          13.9  0.661060
# 7          14.1  0.724219
# 8           9.2 -0.823168
# 9          12.4  0.187371
# 10         13.7  0.597902
# 11         10.6 -0.381057
# 12         21.5  3.061089
# 13         12.0  0.061053
# 14          9.3 -0.791588
# 15         11.2 -0.191581
# 16          3.3 -2.686348
# 17         12.4  0.187371
# 18         12.3  0.155791
# 19         13.8  0.629481
# 20         10.5 -0.412636
# 21         10.4 -0.444216
# 22         15.0  1.008433
# 23         12.7  0.282109
# 24         14.4  0.818957
# 25         11.0 -0.254740
# 26          9.1 -0.854747
# 27         10.2 -0.507374
# 28         12.4  0.187371
# 29          7.0 -1.517913
# 30         14.8  0.945274

# %%
df['Z-score'].describe()
# Out:
# count    3.000000e+01
# mean     7.401487e-18
# std      1.000000e+00
# min     -2.686348e+00
# 25%     -4.915848e-01
# 50%      6.105335e-02
# 75%      6.215863e-01
# max      3.061089e+00
# Name: Z-score, dtype: float64

# %% [markdown]
# # Histogram

# %%
plt.hist(df['Current'], bins = 5,
         alpha = 0.8,
         color = '#126782',
         edgecolor = '#1C1F24')
plt.show()

# %%
plt.hist(df['Current'], bins = 5,
         alpha = 0.8,
         color = '#126782',
         edgecolor = '#1C1F24')
plt.title('Histogram of Current Values',
          font= 'Palatino Linotype',
          fontsize=12,)
plt.xlabel('Current (mA)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Normal Distribution

# %%
# normal distribution
mean = df['Current'].mean()
std = df['Current'].std(ddof=1)

# x-axis
x_min =df['Current'].min()
x_max =df['Current'].max()

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x, mean, std)

plt.plot(x ,p, 
         color = '#126782',
         linewidth=2)
plt.title('Normal Distribution of Current Values',
          font = 'Palatino Linotype',
          fontsize=12)
plt.xlabel('Current (mA)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Current'], bins = 5,
         density=True,
         alpha = 0.8,
         color = '#126782',
         edgecolor = '#1C1F24')
plt.title('Histogram of Current Values',
          font= 'Palatino Linotype',
          fontsize=12,)
plt.xlabel('Current (mA)')
plt.ylabel('Frequency')


p = stats.norm.pdf(x, mean, std)

plt.plot(x ,p, 
         color = 'orange',
         linewidth=2)
plt.show()

# %%
# standard normal distribution N(0,1)

x_min =df['Z-score'].min()
x_max =df['Z-score'].max()

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x, df['Z-score'].mean(), df['Z-score'].std(ddof=1))


plt.plot(x ,p, 
         color = '#126782',
         linewidth=2)
plt.title('Normal Distribution of Z-score Values',
          font = 'Palatino Linotype',
          fontsize=12)
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.show()
